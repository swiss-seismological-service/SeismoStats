# %% [markdown]
# # Catalog Examples

# %%
from seismostats import FDSNWSEventClient
from seismostats import Catalog, ForecastCatalog, GRRateGrid
from datetime import datetime

# %%
start_time = datetime(2021,1,1)
end_time = datetime(2022,1,1)

min_longitude = 5
max_longitude = 11
min_latitude = 45
max_latitude = 48
min_magnitude = 2

url = 'http://eida.ethz.ch/fdsnws/event/1/query'
client = FDSNWSEventClient(url)
df_sed = client.get_events(
    start_time=start_time,
    end_time=end_time,
    min_magnitude=min_magnitude,
    min_longitude=min_longitude,
    max_longitude=max_longitude,
    min_latitude=min_latitude,
    max_latitude=max_latitude,
    include_all_magnitudes=True,
    event_type='earthquake',
    include_uncertainty=True,
    include_ids=True)
df_sed
# Out:
#                                    eventID  event_type  \
# 0   smi:ch.ethz.sed/sc20a/Event/2021zqxyri  earthquake
# 1   smi:ch.ethz.sed/sc20a/Event/2021zihlix  earthquake
# 2   smi:ch.ethz.sed/sc20a/Event/2021zhdzar  earthquake
# 3   smi:ch.ethz.sed/sc20a/Event/2021zamwcn  earthquake
# 4   smi:ch.ethz.sed/sc20a/Event/2021yzugwx  earthquake
# ..                                     ...         ...
# 91         smi:ch.ethz.sed/sc3a/2021cniflg  earthquake
# 92         smi:ch.ethz.sed/sc3a/2021ckhxfk  earthquake
# 93         smi:ch.ethz.sed/sc3a/2021cgvzgl  earthquake
# 94         smi:ch.ethz.sed/sc3a/2021bjlljq  earthquake
# 95         smi:ch.ethz.sed/sc3a/2021ahiayb  earthquake
#
#                          time   latitude latitude_uncertainty  longitude  \
# 0  2021-12-30 07:43:14.681975  46.051445         0.1222628824   7.388025
# 1  2021-12-25 14:49:40.125942  47.371755         0.1363265577   6.917057
# 2  2021-12-24 23:59:56.706839  47.373494          0.140019287   6.918607
# 3  2021-12-21 08:56:46.307560  47.075317         0.1183643238   6.613590
# 4  2021-12-20 23:36:00.020508  45.937659         0.5140998857  10.887420
# ..                        ...        ...                  ...        ...
# 91 2021-02-05 13:58:37.339370  47.755435         0.2768619939   8.826280
# 92 2021-02-03 22:35:36.860227  46.979183         0.2211121752   7.441018
# 93 2021-02-02 01:22:29.854540  46.448367           0.21466477  10.209043
# 94 2021-01-20 07:21:43.968833  45.607265          0.353045372   6.914348
# 95 2021-01-04 23:33:46.277509  47.285307         0.6089577686  10.063897
#
#    longitude_uncertainty         depth depth_uncertainty evaluationmode  ...  \
# 0           0.1007121534   1181.640625       274.9552879         manual  ...
# 1           0.1277685645   3364.257812       1036.395075         manual  ...
# 2           0.1174757855   4423.828125       692.7322216         manual  ...
# 3           0.1467303134   5136.718750        570.791371         manual  ...
# 4           0.2678900939  10517.578120       386.4332861         manual  ...
# ..                   ...           ...               ...            ...  ...
# 91          0.2656020058   9790.039062       699.3952815         manual  ...
# 92          0.2177237663   4077.148438       794.7783124         manual  ...
# 93           0.154515209   6137.695312       472.5675277         manual  ...
# 94          0.3988253348   8335.156250       1511.597803         manual  ...
# 95          0.4403913609   6248.046875       2672.770805         manual  ...
#
#                          magnitude_MWspec_magnitudeID  magnitude_MLv  \
# 0   smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    2.301758471
# 1   smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    3.206767678
# 2   smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...     3.74585924
# 3   smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    2.594656628
# 4   smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    1.999443788
# ..                                                ...            ...
# 91                                                NaN    1.719236171
# 92  smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    2.612462067
# 93  smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    2.069442787
# 94  smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite...    1.998272686
# 95  smi:ch.ethz.sed/wfa.ethz.ch/magnitude/MWspec/d...     1.74918801
#
#    magnitude_MLv_uncertainty  \
# 0               0.2729312832
# 1               0.3278561212
# 2                0.393233673
# 3               0.2672710887
# 4               0.1331781857
# ..                       ...
# 91              0.4326049696
# 92               0.264557289
# 93              0.5843922428
# 94              0.4331054981
# 95              0.3234048292
#
#                             magnitude_MLv_magnitudeID magnitude_MLh  \
# 0   smi:ch.ethz.sed/sc20ag/Magnitude/2022010307031...          2.49
# 1   smi:ch.ethz.sed/sc20ag/Magnitude/2021122819430...           3.5
# 2   smi:ch.ethz.sed/sc20ag/Magnitude/2021122716333...          4.06
# 3   smi:ch.ethz.sed/sc20ag/Magnitude/2021122809023...          2.86
# 4   smi:ch.ethz.sed/sc20ag/Magnitude/2021122110441...          1.76
# ..                                                ...           ...
# 91  smi:ch.ethz.sed/sc3a/Magnitude/20210205174337....           1.9
# 92  smi:ch.ethz.sed/sc3a/Magnitude/20210207204645....          2.82
# 93  smi:ch.ethz.sed/sc20ag/Magnitude/2022011812331...           1.9
# 94  smi:ch.ethz.sed/sc3a/Magnitude/20210120103501....          1.97
# 95  smi:ch.ethz.sed/sc3a/Magnitude/20210105075342....          1.94
#
#    magnitude_MLh_uncertainty  \
# 0                 0.23854491
# 1                0.272435385
# 2               0.3127250086
# 3               0.2414400072
# 4               0.2539158048
# ..                       ...
# 91              0.2171883359
# 92              0.2194575558
# 93              0.2525366761
# 94              0.2142778221
# 95              0.2080507104
#
#                             magnitude_MLh_magnitudeID magnitude_MLhc  \
# 0   smi:ch.ethz.sed/sc20ag/Magnitude/2022010307031...    2.510115344
# 1   smi:ch.ethz.sed/sc20ag/Magnitude/2021122819430...    3.539687307
# 2   smi:ch.ethz.sed/sc20ag/Magnitude/2021122716333...    4.102738426
# 3   smi:ch.ethz.sed/sc20ag/Magnitude/2021122809023...    2.908839011
# 4   smi:ch.ethz.sed/sc20ag/Magnitude/2021122110441...    2.110428524
# ..                                                ...            ...
# 91  smi:ch.ethz.sed/sc3a/Magnitude/20210205174337....    1.972256102
# 92  smi:ch.ethz.sed/sc3a/Magnitude/20210207204645....    2.835083023
# 93  smi:ch.ethz.sed/sc20ag/Magnitude/2022011812331...    2.071647738
# 94  smi:ch.ethz.sed/sc3a/Magnitude/20210120103501....    2.109462073
# 95  smi:ch.ethz.sed/sc3a/Magnitude/20210105075342....    1.950813241
#
#    magnitude_MLhc_uncertainty  \
# 0                  0.23854491
# 1                 0.272435385
# 2                0.3127250086
# 3                0.2414400072
# 4                0.2539158048
# ..                        ...
# 91               0.2171883359
# 92               0.2194575558
# 93               0.2525366761
# 94               0.2142778221
# 95               0.2080507104
#
#                            magnitude_MLhc_magnitudeID
# 0   smi:ch.ethz.sed/sc20ag/Magnitude/2022010307031...
# 1   smi:ch.ethz.sed/sc20ag/Magnitude/2021122819430...
# 2   smi:ch.ethz.sed/sc20ag/Magnitude/2021122716333...
# 3   smi:ch.ethz.sed/sc20ag/Magnitude/2021122809023...
# 4   smi:ch.ethz.sed/sc20ag/Magnitude/2021122110441...
# ..                                                ...
# 91  smi:ch.ethz.sed/sc3a/Magnitude/20210205174337....
# 92  smi:ch.ethz.sed/sc3a/Magnitude/20210207204645....
# 93  smi:ch.ethz.sed/sc20ag/Magnitude/2022011812331...
# 94  smi:ch.ethz.sed/sc3a/Magnitude/20210120103501....
# 95  smi:ch.ethz.sed/sc3a/Magnitude/20210105075342....
#
# [96 rows x 28 columns]

# %%
type(df_sed)
# Out:
# seismostats.catalogs.catalog.Catalog

# %%
df_sed.to_quakeml()
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<q:quakeml xmlns="http://quakeml.org/xmlns/bed/1.2" xmlns:q="http://quakeml.org/xmlns/quakeml/1.2">\n    <eventParameters publicID="smi:org.gfz-potsdam.de/geofon/EventParameters"> \n         \n        <event publicID="smi:ch.ethz.sed/sc20a/Event/2021zqxyri">\n            <creationInfo>\n                <agencyID> </agencyID>\n                <author> </author>\n            </creationInfo>\n\n            <magnitude publicID="smi:ch.ethz.sed/sc20ag/Magnitude/20220103070310.700951.80206">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.510115344</value><uncertainty>0.23854491</uncertainty></mag>\n                <type>MLhc</type>\n                <originID>smi:ch.ethz.sed/sc20ag/Origin/NLL.20220103070248.816904.80080</originID>\n            </magnitude>\n\n            \n            <magnitude publicID="smi:ch.ethz.sed/wfa.ethz.ch/magnitude/AutoSite/8fGgNbULLJeYUny">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.74</value><uncertainty>0.04</uncertainty></mag>\n                <type>MWspec</type>\n                <originID>smi:ch.ethz.sed/sc20ag/Origin/NLL.20220103070248.816904.80080</originID>\n            </magnitude>\n            \n            <magnitude publicID="smi:ch.ethz.sed/sc20ag/Magnitude/20220103070310.752473.80241">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.301758471</value><uncertainty>0.2729312832</uncertainty></mag>\n                <type>MLv</type>\n                <originID>smi:ch.ethz.sed/sc20ag/Origin/NLL.20220103070248.816904.80080</originID>\n            </magnitude>\n            \n            <magnitude publicID="smi:ch.ethz.sed/sc20ag/Magnitude/20220103070310.700951.80206.mlhc2mlh">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.49</value><uncertainty>0.23854491</uncertainty></mag>\n                <type>MLh</type>\n                <originID>smi:ch.ethz.sed/sc20ag/Origin/NLL.20220103070248.816904.80080</originID>\n            </magnitude>\n            \n\n            <origin publicID="smi:ch.ethz.sed/sc20ag/Origin/NLL.20220103070248.816904.80080">\n                <time>\n                    <value>2021-12-30T07:43:14.681975Z</value>\n                </time>\n                <longitude>\n                    <value>7.388024848</value><uncertainty>0.1007121534</uncertainty></longitude>\n                <latitude>\n                    <value>46.05144527</value><uncertainty>0.1222628824</uncertainty></latitude>\n                <evaluationMode>manual</evaluationMode>\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <depth>\n                    <value>1181.640625</value><uncertainty>274.9552879</uncertainty></depth>\n                <quality>\n                    </quality>\n            </origin>\n\n            <preferredOriginID>smi:ch.ethz.sed/sc20ag/Origin/NLL.20220103070248.816904.80080</preferredOriginID>\n            <preferredMagnitudeID>smi:ch.ethz.sed/sc20ag/Magnitude/20220103070310.700951.80206</preferredMagnitudeID>\n            <type>earthquake</type>\n\n        </event> \n         \n        <event publicID="smi:ch.ethz.sed/sc20a/Event/2021zihlix">\n            <creationInfo>\n                <agencyID> </agencyID>\n                <author> </author>\n            </creationInfo>\n\n            <magnitude publicID="smi:ch.ethz.sed/sc2 ...

# %%
df_sed_drop = df_sed.drop_uncertainties().drop_ids().bin_magnitudes(0.1)
df_sed_drop
# Out:
#     event_type                       time   latitude  longitude         depth  \
# 0   earthquake 2021-12-30 07:43:14.681975  46.051445   7.388025   1181.640625
# 1   earthquake 2021-12-25 14:49:40.125942  47.371755   6.917057   3364.257812
# 2   earthquake 2021-12-24 23:59:56.706839  47.373494   6.918607   4423.828125
# 3   earthquake 2021-12-21 08:56:46.307560  47.075317   6.613590   5136.718750
# 4   earthquake 2021-12-20 23:36:00.020508  45.937659  10.887420  10517.578120
# ..         ...                        ...        ...        ...           ...
# 91  earthquake 2021-02-05 13:58:37.339370  47.755435   8.826280   9790.039062
# 92  earthquake 2021-02-03 22:35:36.860227  46.979183   7.441018   4077.148438
# 93  earthquake 2021-02-02 01:22:29.854540  46.448367  10.209043   6137.695312
# 94  earthquake 2021-01-20 07:21:43.968833  45.607265   6.914348   8335.156250
# 95  earthquake 2021-01-04 23:33:46.277509  47.285307  10.063897   6248.046875
#
#    evaluationmode  magnitude magnitude_type magnitude_MWspec magnitude_MLv  \
# 0          manual        2.5           MLhc             2.74   2.301758471
# 1          manual        3.5           MLhc             3.16   3.206767678
# 2          manual        4.1           MLhc              3.6    3.74585924
# 3          manual        2.9           MLhc             2.86   2.594656628
# 4          manual        2.1           MLhc             2.22   1.999443788
# ..            ...        ...            ...              ...           ...
# 91         manual        2.0           MLhc              NaN   1.719236171
# 92         manual        2.8           MLhc             2.79   2.612462067
# 93         manual        2.1           MLhc             2.23   2.069442787
# 94         manual        2.1           MLhc             1.91   1.998272686
# 95         manual        2.0           MLhc             2.08    1.74918801
#
#    magnitude_MLh magnitude_MLhc
# 0           2.49    2.510115344
# 1            3.5    3.539687307
# 2           4.06    4.102738426
# 3           2.86    2.908839011
# 4           1.76    2.110428524
# ..           ...            ...
# 91           1.9    1.972256102
# 92          2.82    2.835083023
# 93           1.9    2.071647738
# 94          1.97    2.109462073
# 95          1.94    1.950813241
#
# [96 rows x 12 columns]

# %%
type(df_sed_drop)
# Out:
# seismostats.catalogs.catalog.Catalog

# %%
dropped = df_sed_drop.drop(columns=['magnitude'])
type(dropped)
# Out:
# pandas.core.frame.DataFrame

# %%
dropped = Catalog(dropped)
type(dropped)
# Out:
# seismostats.catalogs.catalog.Catalog

# %%
dropped.bin_magnitudes(0.1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dropped.bin_magnitudes(0.1)
#
# File ~/Documents/Codes_and_tools/SeismoStats/seismostats/utils/__init__.py:58, in require_cols.<locals>.decorator_require.<locals>.wrapper_require(self, *args, **kwargs)
#      56     require = [col for col in require if col not in exclude]
#      57 if not _check_required_cols(self, require):
# ---> 58     raise AttributeError(
#      59         "Catalog is missing the following columns "
#      60         f'for execution of the method "{func.__name__}": '
#      61         f"{set(require).difference(set(self.columns))}."
#      62     )
#      63 value = func(self, *args, **kwargs)
#      64 return value
#
# AttributeError: Catalog is missing the following columns for execution of the method "bin_magnitudes": {'magnitude'}.

# %%
df_sed_drop.to_quakeml()
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<q:quakeml xmlns="http://quakeml.org/xmlns/bed/1.2" xmlns:q="http://quakeml.org/xmlns/quakeml/1.2">\n    <eventParameters publicID="smi:org.gfz-potsdam.de/geofon/EventParameters"> \n         \n        <event publicID="8a24473dab064b3dbf88e5f0610b5279">\n            <creationInfo>\n                <agencyID> </agencyID>\n                <author> </author>\n            </creationInfo>\n\n            <magnitude publicID="b93506bd5ffb4a16897cafe7ba4b155b">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.5</value></mag>\n                <type>MLhc</type>\n                <originID>e396d17e923b4a0a922ee9964cbfc4c4</originID>\n            </magnitude>\n\n            \n            <magnitude publicID="">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.74</value></mag>\n                <type>MWspec</type>\n                <originID>e396d17e923b4a0a922ee9964cbfc4c4</originID>\n            </magnitude>\n            \n            <magnitude publicID="">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.301758471</value></mag>\n                <type>MLv</type>\n                <originID>e396d17e923b4a0a922ee9964cbfc4c4</originID>\n            </magnitude>\n            \n            <magnitude publicID="">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>2.49</value></mag>\n                <type>MLh</type>\n                <originID>e396d17e923b4a0a922ee9964cbfc4c4</originID>\n            </magnitude>\n            \n\n            <origin publicID="e396d17e923b4a0a922ee9964cbfc4c4">\n                <time>\n                    <value>2021-12-30T07:43:14.681975Z</value>\n                </time>\n                <longitude>\n                    <value>7.388024848</value></longitude>\n                <latitude>\n                    <value>46.05144527</value></latitude>\n                <evaluationMode>manual</evaluationMode>\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <depth>\n                    <value>1181.640625</value></depth>\n                <quality>\n                    </quality>\n            </origin>\n\n            <preferredOriginID>e396d17e923b4a0a922ee9964cbfc4c4</preferredOriginID>\n            <preferredMagnitudeID>b93506bd5ffb4a16897cafe7ba4b155b</preferredMagnitudeID>\n            <type>earthquake</type>\n\n        </event> \n         \n        <event publicID="e089e4b328294ee187e364da6b7192a1">\n            <creationInfo>\n                <agencyID> </agencyID>\n                <author> </author>\n            </creationInfo>\n\n            <magnitude publicID="bd7a4f0dd9c54296b5b52fc1e259ac0c">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>3.5</value></mag>\n                <type>MLhc</type>\n                <originID>e9670eb4263543469b877a0f745c83e2</originID>\n            </magnitude>\n\n            \n            <magnitude publicID="">\n                <creationInfo>\n                    <agencyID> </agencyID>\n                    <author> </author>\n                </creationInfo>\n                <mag>\n                    <value>3.16</value></mag>\n                <type>MWspec</type>\n                <originID ...

# %%
forecast_sed = df_sed.copy()
forecast_sed['catalog_id'] = 1
forecast_sed = ForecastCatalog(forecast_sed)
forecast_sed.strip(inplace=True)
forecast_sed
# Out:
#                          time   latitude  longitude         depth  magnitude  \
# 0  2021-12-30 07:43:14.681975  46.051445   7.388025   1181.640625   2.510115
# 1  2021-12-25 14:49:40.125942  47.371755   6.917057   3364.257812   3.539687
# 2  2021-12-24 23:59:56.706839  47.373494   6.918607   4423.828125   4.102738
# 3  2021-12-21 08:56:46.307560  47.075317   6.613590   5136.718750   2.908839
# 4  2021-12-20 23:36:00.020508  45.937659  10.887420  10517.578120   2.110429
# ..                        ...        ...        ...           ...        ...
# 91 2021-02-05 13:58:37.339370  47.755435   8.826280   9790.039062   1.972256
# 92 2021-02-03 22:35:36.860227  46.979183   7.441018   4077.148438   2.835083
# 93 2021-02-02 01:22:29.854540  46.448367  10.209043   6137.695312   2.071648
# 94 2021-01-20 07:21:43.968833  45.607265   6.914348   8335.156250   2.109462
# 95 2021-01-04 23:33:46.277509  47.285307  10.063897   6248.046875   1.950813
#
#     catalog_id
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 91           1
# 92           1
# 93           1
# 94           1
# 95           1
#
# [96 rows x 6 columns]

# %%
type(forecast_sed)
# Out:
# seismostats.catalogs.catalog.ForecastCatalog

# %%
RAW_DATA = {
    'longitude_min': [-180, -90, 0, 90],
    'longitude_max': [-90, 0, 90, 180],
    'latitude_min': [-90, -45, 0, 45],
    'latitude_max': [-45, 0, 45, 90],
    'depth_min': [0, 10, 20, 30],
    'depth_max': [10, 20, 30, 40],
    'number_events': [100, 200, 300, 400],
    'a': [1.0, 1.5, 2.0, 2.5],
    'b': [0.5, 0.6, 0.7, 0.8],
    'mc': [4.0, 4.5, 5.0, 5.5]
}
rategrid = GRRateGrid(RAW_DATA, starttime=datetime(2020,1,1), endtime=datetime(2020,2,1))
rategrid
# Out:
#    longitude_min  longitude_max  latitude_min  latitude_max  depth_min  \
# 0           -180            -90           -90           -45          0
# 1            -90              0           -45             0         10
# 2              0             90             0            45         20
# 3             90            180            45            90         30
#
#    depth_max  number_events    a    b   mc
# 0         10            100  1.0  0.5  4.0
# 1         20            200  1.5  0.6  4.5
# 2         30            300  2.0  0.7  5.0
# 3         40            400  2.5  0.8  5.5

# %%
rategrid.starttime
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
rategrid.add_time_index(endtime=False)
# Out:
#                     longitude_min  longitude_max  latitude_min  latitude_max  \
# starttime  cell_id
# 2020-01-01 0                 -180            -90           -90           -45
#            1                  -90              0           -45             0
#            2                    0             90             0            45
#            3                   90            180            45            90
#
#                     depth_min  depth_max  number_events    a    b   mc
# starttime  cell_id
# 2020-01-01 0                0         10            100  1.0  0.5  4.0
#            1               10         20            200  1.5  0.6  4.5
#            2               20         30            300  2.0  0.7  5.0
#            3               30         40            400  2.5  0.8  5.5
